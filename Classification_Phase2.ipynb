# %%
import pandas as pd
import joblib

model = joblib.load("saved_model/new_model.pkl")

new_data = {
    "age": 48,
    "bp": 80,
    "al": 1,
    "su": 0,
    "bgr": 140,
    "bu": 36,
    "sc": 1.2,
    "sod": 138,
    "pot": 4.3,
    "hrmo": 13.5,
    "pcv": 42,
    "wc": 7800,
    "rc": 4.8,
    "sg_b": 0,
    "sg_c": 1,
    "sg_d": 0,
    "sg_e": 0,
    "rbc_normal": 1,
    "pc_normal": 1,
    "pcc_present": 0,
    "ba_present": 0,
    "htn_yes": 1,
    "dm_yes": 0,
    "cad_yes": 0,
    "appet_yes": 1,
    "pe_yes": 0,
    "ane_yes": 0,
}
input_data = pd.DataFrame([new_data])
prediction = model.predict(input_data)
if prediction[0]:
    print("yes")
else:
    print("No")
# Out:
# yes
